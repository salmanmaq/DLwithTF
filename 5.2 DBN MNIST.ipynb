# %%
#urllib is used to download the utils file from deeplearning.net
import urllib
response = urllib.urlopen('http://deeplearning.net/tutorial/code/utils.py')
content = response.read()
target = open('utils.py', 'w')
target.write(content)
target.close()

import math
import tensorflow as tf
import numpy as np
from PIL import Image
from utils import tile_raster_images

# %%
#Class that defines the behavior of the RBM
class RBM(object):
    
    def __init__(self, input_size, output_size):
        #Defining the hyperparameters
        self._input_size = input_size #Size of input
        self._output_size = output_size #Size of output
        self.epochs = 50 #Amount of training iterations
        self.learning_rate = 1.0 #The step used in gradient descent
        self.batchsize = 100 #The size of how much data will be used for training per sub iteration
        
        #Initializing weights and biases as matrices full of zeroes
        self.w = np.zeros([input_size, output_size], np.float32) #Creates and initializes the weights with 0
        self.hb = np.zeros([output_size], np.float32) #Creates and initializes the hidden biases with 0
        self.vb = np.zeros([input_size], np.float32) #Creates and initializes the visible biases with 0


    #Fits the result from the weighted visible layer plus the bias into a sigmoid curve
    def prob_h_given_v(self, visible, w, hb):
        #Sigmoid 
        return tf.nn.sigmoid(tf.matmul(visible, w) + hb)

    #Fits the result from the weighted hidden layer plus the bias into a sigmoid curve
    def prob_v_given_h(self, hidden, w, vb):
        return tf.nn.sigmoid(tf.matmul(hidden, tf.transpose(w)) + vb)
    
    #Generate the sample probability
    def sample_prob(self, probs):
        return tf.nn.relu(tf.sign(probs - tf.random_uniform(tf.shape(probs))))

    #Training method for the model
    def train(self, X):
        #Create the placeholders for our parameters
        _w = tf.placeholder("float", [self._input_size, self._output_size])
        _hb = tf.placeholder("float", [self._output_size])
        _vb = tf.placeholder("float", [self._input_size])
        
        prv_w = np.zeros([self._input_size, self._output_size], np.float32) #Creates and initializes the weights with 0
        prv_hb = np.zeros([self._output_size], np.float32) #Creates and initializes the hidden biases with 0
        prv_vb = np.zeros([self._input_size], np.float32) #Creates and initializes the visible biases with 0

        
        cur_w = np.zeros([self._input_size, self._output_size], np.float32)
        cur_hb = np.zeros([self._output_size], np.float32)
        cur_vb = np.zeros([self._input_size], np.float32)
        v0 = tf.placeholder("float", [None, self._input_size])
        
        #Initialize with sample probabilities
        h0 = self.sample_prob(self.prob_h_given_v(v0, _w, _hb))
        v1 = self.sample_prob(self.prob_v_given_h(h0, _w, _vb))
        h1 = self.prob_h_given_v(v1, _w, _hb)
        
        #Create the Gradients
        positive_grad = tf.matmul(tf.transpose(v0), h0)
        negative_grad = tf.matmul(tf.transpose(v1), h1)
        
        #Update learning rates for the layers
        update_w = _w + self.learning_rate *(positive_grad - negative_grad) / tf.to_float(tf.shape(v0)[0])
        update_vb = _vb +  self.learning_rate * tf.reduce_mean(v0 - v1, 0)
        update_hb = _hb +  self.learning_rate * tf.reduce_mean(h0 - h1, 0)
        
        #Find the error rate
        err = tf.reduce_mean(tf.square(v0 - v1))
        
        #Training loop
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            #For each epoch
            for epoch in range(self.epochs):
                #For each step/batch
                for start, end in zip(range(0, len(X), self.batchsize),range(self.batchsize,len(X), self.batchsize)):
                    batch = X[start:end]
                    #Update the rates
                    cur_w = sess.run(update_w, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_hb = sess.run(update_hb, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_vb = sess.run(update_vb, feed_dict={v0: batch, _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    prv_w = cur_w
                    prv_hb = cur_hb
                    prv_vb = cur_vb
                error=sess.run(err, feed_dict={v0: X, _w: cur_w, _vb: cur_vb, _hb: cur_hb})
                print 'Epoch: %d' % epoch,'reconstruction error: %f' % error
            self.w = prv_w
            self.hb = prv_hb
            self.vb = prv_vb

    #Create expected output for our DBN
    def rbm_outpt(self, X):
        input_X = tf.constant(X)
        _w = tf.constant(self.w)
        _hb = tf.constant(self.hb)
        out = tf.nn.sigmoid(tf.matmul(input_X, _w) + _hb)
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            return sess.run(out)

# %%
#Getting the MNIST data provided by Tensorflow
from tensorflow.examples.tutorials.mnist import input_data

#Loading in the mnist data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
trX, trY, teX, teY = mnist.train.images, mnist.train.labels, mnist.test.images,\
    mnist.test.labels
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
RBM_hidden_sizes = [500, 200 , 50 ] #create 2 layers of RBM with size 400 and 100

#Since we are training, set input as training data
inpX = trX

#Create list to hold our RBMs
rbm_list = []

#Size of inputs is the number of inputs in the training set
input_size = inpX.shape[1]

#For each RBM we want to generate
for i, size in enumerate(RBM_hidden_sizes):
    print 'RBM: ',i,' ',input_size,'->', size
    rbm_list.append(RBM(input_size, size))
    input_size = size
# Out:
# RBM:  0   784 -> 500
# RBM:  1   500 -> 200
# RBM:  2   200 -> 50

# %%
#For each RBM in our list
for rbm in rbm_list:
    print 'New RBM:'
    #Train a new one
    rbm.train(inpX) 
    #Return the output layer
    inpX = rbm.rbm_outpt(inpX)
# Out:
# New RBM:
# Epoch: 0 reconstruction error: 0.060494
# Epoch: 1 reconstruction error: 0.052361
# Epoch: 2 reconstruction error: 0.048482
# Epoch: 3 reconstruction error: 0.046817
# Epoch: 4 reconstruction error: 0.045608
# Epoch: 5 reconstruction error: 0.044868
# Epoch: 6 reconstruction error: 0.044434
# Epoch: 7 reconstruction error: 0.043251
# Epoch: 8 reconstruction error: 0.042882
# Epoch: 9 reconstruction error: 0.042593
# Epoch: 10 reconstruction error: 0.042170
# Epoch: 11 reconstruction error: 0.041780
# Epoch: 12 reconstruction error: 0.041498
# Epoch: 13 reconstruction error: 0.041199
# Epoch: 14 reconstruction error: 0.041391
# Epoch: 15 reconstruction error: 0.041137
# Epoch: 16 reconstruction error: 0.041330
# Epoch: 17 reconstruction error: 0.040422
# Epoch: 18 reconstruction error: 0.040657
# Epoch: 19 reconstruction error: 0.041000
# Epoch: 20 reconstruction error: 0.040969
# Epoch: 21 reconstruction error: 0.040487
# Epoch: 22 reconstruction error: 0.040920
# Epoch: 23 reconstruction error: 0.040382
# Epoch: 24 reconstruction error: 0.040347
# Epoch: 25 reconstruction error: 0.040988
# Epoch: 26 reconstruction error: 0.040429
# Epoch: 27 reconstruction error: 0.040060
# Epoch: 28 reconstruction error: 0.040266
# Epoch: 29 reconstruction error: 0.040237
# Epoch: 30 reconstruction error: 0.040990
# Epoch: 31 reconstruction error: 0.040713
# Epoch: 32 reconstruction error: 0.040158
# Epoch: 33 reconstruction error: 0.040391
# Epoch: 34 reconstruction error: 0.039970
# Epoch: 35 reconstruction error: 0.039910
# Epoch: 36 reconstruction error: 0.040432
# Epoch: 37 reconstruction error: 0.040266
# Epoch: 38 reconstruction error: 0.040127
# Epoch: 39 reconstruction error: 0.039622
# Epoch: 40 reconstruction error: 0.039739
# Epoch: 41 reconstruction error: 0.040169
# Epoch: 42 reconstruction error: 0.039522
# Epoch: 43 reconstruction error: 0.039718
# Epoch: 44 reconstruction error: 0.040135
# Epoch: 45 reconstruction error: 0.039404
# Epoch: 46 reconstruction error: 0.039738
# Epoch: 47 reconstruction error: 0.039570
# Epoch: 48 reconstruction error: 0.039910
# Epoch: 49 reconstruction error: 0.039547
# New RBM:
# Epoch: 0 reconstruction error: 0.042126
# Epoch: 1 reconstruction error: 0.037628
# Epoch: 2 reconstruction error: 0.035186
# Epoch: 3 reconstruction error: 0.033577
# Epoch: 4 reconstruction error: 0.032507
# Epoch: 5 reconstruction error: 0.031667
# Epoch: 6 reconstruction error: 0.031074
# Epoch: 7 reconstruction error: 0.030210
# Epoch: 8 reconstruction error: 0.029518
# Epoch: 9 reconstruction error: 0.029074
# Epoch: 10 reconstruction error: 0.028552
# Epoch: 11 reconstruction error: 0.028242
# Epoch: 12 reconstruction error: 0.028050
# Epoch: 13 reconstruction error: 0.027741
# Epoch: 14 reconstruction error: 0.027409
# Epoch: 15 reconstruction error: 0.027193
# Epoch: 16 reconstruction error: 0.027109
# Epoch: 17 reconstruction error: 0.027035
# Epoch: 18 reconstruction error: 0.026729
# Epoch: 19 reconstruction error: 0.026474
# Epoch: 20 reconstruction error: 0.026351
# Epoch: 21 reconstruction error: 0.026199
# Epoch: 22 reconstruction error: 0.025971
# Epoch: 23 reconstruction error: 0.025822
# Epoch: 24 reconstruction error: 0.026046
# Epoch: 25 reconstruction error: 0.025795
# Epoch: 26 reconstruction error: 0.025515
# Epoch: 27 reconstruction error: 0.025552
# Epoch: 28 reconstruction error: 0.025408
# Epoch: 29 reconstruction error: 0.025160
# Epoch: 30 reconstruction error: 0.025107
# Epoch: 31 reconstruction error: 0.025136
# Epoch: 32 reconstruction error: 0.024905
# Epoch: 33 reconstruction error: 0.025045
# Epoch: 34 reconstruction error: 0.024875
# Epoch: 35 reconstruction error: 0.024738
# Epoch: 36 reconstruction error: 0.024708
# Epoch: 37 reconstruction error: 0.024646
# Epoch: 38 reconstruction error: 0.024707
# Epoch: 39 reconstruction error: 0.024466
# Epoch: 40 reconstruction error: 0.024422
# Epoch: 41 reconstruction error: 0.024424
# Epoch: 42 reconstruction error: 0.024417
# Epoch: 43 reconstruction error: 0.024205
# Epoch: 44 reconstruction error: 0.024278
# Epoch: 45 reconstruction error: 0.024198
# Epoch: 46 reconstruction error: 0.024152
# Epoch: 47 reconstruction error: 0.024055
# Epoch: 48 reconstruction error: 0.024189
# Epoch: 49 reconstruction error: 0.024241
# New RBM:
# Epoch: 0 reconstruction error: 0.049969
# Epoch: 1 reconstruction error: 0.046487
# Epoch: 2 reconstruction error: 0.045132
# Epoch: 3 reconstruction error: 0.044258
# Epoch: 4 reconstruction error: 0.043799
# Epoch: 5 reconstruction error: 0.043528
# Epoch: 6 reconstruction error: 0.042704
# Epoch: 7 reconstruction error: 0.042294
# Epoch: 8 reconstruction error: 0.042501
# Epoch: 9 reconstruction error: 0.042403
# Epoch: 10 reconstruction error: 0.042117
# Epoch: 11 reconstruction error: 0.041826
# Epoch: 12 reconstruction error: 0.041975
# Epoch: 13 reconstruction error: 0.041522
# Epoch: 14 reconstruction error: 0.041884
# Epoch: 15 reconstruction error: 0.041556
# Epoch: 16 reconstruction error: 0.041030
# Epoch: 17 reconstruction error: 0.041297
# Epoch: 18 reconstruction error: 0.041262
# Epoch: 19 reconstruction error: 0.041285
# Epoch: 20 reconstruction error: 0.041450
# Epoch: 21 reconstruction error: 0.040815
# Epoch: 22 reconstruction error: 0.040981
# Epoch: 23 reconstruction error: 0.041301
# Epoch: 24 reconstruction error: 0.041272
# Epoch: 25 reconstruction error: 0.040927
# Epoch: 26 reconstruction error: 0.041283
# Epoch: 27 reconstruction error: 0.041325
# Epoch: 28 reconstruction error: 0.041396
# Epoch: 29 reconstruction error: 0.041095
# Epoch: 30 reconstruction error: 0.040983
# Epoch: 31 reconstruction error: 0.041089
# Epoch: 32 reconstruction error: 0.040700
# Epoch: 33 reconstruction error: 0.040829
# Epoch: 34 reconstruction error: 0.040926
# Epoch: 35 reconstruction error: 0.040424
# Epoch: 36 reconstruction error: 0.040838
# Epoch: 37 reconstruction error: 0.040982
# Epoch: 38 reconstruction error: 0.040808
# Epoch: 39 reconstruction error: 0.040846
# Epoch: 40 reconstruction error: 0.040809
# Epoch: 41 reconstruction error: 0.040996
# Epoch: 42 reconstruction error: 0.040859
# Epoch: 43 reconstruction error: 0.040715
# Epoch: 44 reconstruction error: 0.041019
# Epoch: 45 reconstruction error: 0.040998
# Epoch: 46 reconstruction error: 0.040708
# Epoch: 47 reconstruction error: 0.040845
# Epoch: 48 reconstruction error: 0.040640
# Epoch: 49 reconstruction error: 0.040749

# %%
class NN(object):
    
    def __init__(self, sizes, X, Y):
        #Initialize hyperparameters
        self._sizes = sizes
        self._X = X
        self._Y = Y
        self.w_list = []
        self.b_list = []
        self._learning_rate =  1.0
        self._momentum = 0.0
        self._epoches = 10
        self._batchsize = 100
        input_size = X.shape[1]
        
        #initialization loop
        for size in self._sizes + [Y.shape[1]]:
            #Define upper limit for the uniform distribution range
            max_range = 4 * math.sqrt(6. / (input_size + size))
            
            #Initialize weights through a random uniform distribution
            self.w_list.append(
                np.random.uniform( -max_range, max_range, [input_size, size]).astype(np.float32))
            
            #Initialize bias as zeroes
            self.b_list.append(np.zeros([size], np.float32))
            input_size = size
      
    #load data from rbm
    def load_from_rbms(self, dbn_sizes,rbm_list):
        #Check if expected sizes are correct
        assert len(dbn_sizes) == len(self._sizes)
        
        for i in range(len(self._sizes)):
            #Check if for each RBN the expected sizes are correct
            assert dbn_sizes[i] == self._sizes[i]
        
        #If everything is correct, bring over the weights and biases
        for i in range(len(self._sizes)):
            self.w_list[i] = rbm_list[i].w
            self.b_list[i] = rbm_list[i].hb

    #Training method
    def train(self):
        #Create placeholders for input, weights, biases, output
        _a = [None] * (len(self._sizes) + 2)
        _w = [None] * (len(self._sizes) + 1)
        _b = [None] * (len(self._sizes) + 1)
        _a[0] = tf.placeholder("float", [None, self._X.shape[1]])
        y = tf.placeholder("float", [None, self._Y.shape[1]])
        
        #Define variables and activation functoin
        for i in range(len(self._sizes) + 1):
            _w[i] = tf.Variable(self.w_list[i])
            _b[i] = tf.Variable(self.b_list[i])
        for i in range(1, len(self._sizes) + 2):
            _a[i] = tf.nn.sigmoid(tf.matmul(_a[i - 1], _w[i - 1]) + _b[i - 1])
        
        #Define the cost function
        cost = tf.reduce_mean(tf.square(_a[-1] - y))
        
        #Define the training operation (Momentum Optimizer minimizing the Cost function)
        train_op = tf.train.MomentumOptimizer(
            self._learning_rate, self._momentum).minimize(cost)
        
        #Prediction operation
        predict_op = tf.argmax(_a[-1], 1)
        
        #Training Loop
        with tf.Session() as sess:
            #Initialize Variables
            sess.run(tf.global_variables_initializer())
            
            #For each epoch
            for i in range(self._epoches):
                
                #For each step
                for start, end in zip(
                    range(0, len(self._X), self._batchsize), range(self._batchsize, len(self._X), self._batchsize)):
                    
                    #Run the training operation on the input data
                    sess.run(train_op, feed_dict={
                        _a[0]: self._X[start:end], y: self._Y[start:end]})
                
                for j in range(len(self._sizes) + 1):
                    #Retrieve weights and biases
                    self.w_list[j] = sess.run(_w[j])
                    self.b_list[j] = sess.run(_b[j])
                
                print "Accuracy rating for epoch " + str(i) + ": " + str(np.mean(np.argmax(self._Y, axis=1) ==
                              sess.run(predict_op, feed_dict={_a[0]: self._X, y: self._Y})))

# %%
nNet = NN(RBM_hidden_sizes, trX, trY)
nNet.load_from_rbms(RBM_hidden_sizes,rbm_list)
nNet.train()
# Out:
# Accuracy rating for epoch 0: 0.525363636364
# Accuracy rating for epoch 1: 0.680072727273
# Accuracy rating for epoch 2: 0.769545454545
# Accuracy rating for epoch 3: 0.824727272727
# Accuracy rating for epoch 4: 0.8896
# Accuracy rating for epoch 5: 0.908727272727
# Accuracy rating for epoch 6: 0.917054545455
# Accuracy rating for epoch 7: 0.922309090909
# Accuracy rating for epoch 8: 0.926527272727
# Accuracy rating for epoch 9: 0.929036363636
